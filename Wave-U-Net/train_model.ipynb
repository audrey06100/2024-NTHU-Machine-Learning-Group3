# %%
# %cd /content/drive/MyDrive/Wave-U-Net
# Out:
# /content/drive/MyDrive/Wave-U-Net

# %%
# !pip install tensorflow-gpu
# !pip install tqdm pystoi pesq
# !pip install json5
# Out:
# Collecting tensorflow-gpu
#   Downloading tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.6)
# Collecting pystoi
#   Downloading pystoi-0.4.1-py2.py3-none-any.whl.metadata (4.0 kB)
# Collecting pesq
#   Downloading pesq-0.0.4.tar.gz (38 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pystoi) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pystoi) (1.13.1)
# Downloading pystoi-0.4.1-py2.py3-none-any.whl (8.2 kB)
# Building wheels for collected packages: pesq
#   Building wheel for pesq (setup.py) ... done
#   Created wheel for pesq: filename=pesq-0.0.4-cp310-cp310-linux_x86_64.whl size=262942 sha256=825a862d63afb6520ce0d5aac41588c8a6f7d62826b3657c1c0e99a48c0cb83b
#   Stored in directory: /root/.cache/pip/wheels/c5/4e/2c/251524370c0fdd659e99639a0fbd0ca5a782c3aafcd456b28d
# Successfully built pesq
# Installing collected packages: pesq, pystoi
# Successfully installed pesq-0.0.4 pystoi-0.4.1
# Collecting json5
#   Downloading json5-0.10.0-py3-none-any.whl.metadata (34 kB)
# Downloading json5-0.10.0-py3-none-any.whl (34 kB)
# Installing collected packages: json5
# Successfully installed json5-0.10.0

# %% [markdown]
# # Create Dataset .txt Files

# %%
import os
import pandas as pd

# %%
noisy_speech_duration = pd.read_csv('/content/drive/MyDrive/audio/noisy_speech_duration.csv')
noisy_speech_duration.head()
# Out:
#                      filename  duration(s)
# 0  17367893_3-172881-A-48.mp3     4.476100
# 1  17367897_5-210612-A-37.mp3     2.316100
# 2  17367899_3-130998-B-28.mp3     2.532063
# 3  17367900_3-120526-B-37.mp3     2.052063
# 4  17367903_5-204114-A-29.mp3     2.508027

# %%
filtered_duration = noisy_speech_duration[noisy_speech_duration['duration(s)']>1]
filtered_duration = filtered_duration[filtered_duration['duration(s)']<=3]
len(noisy_speech_duration), len(filtered_duration)
# Out:
# (43591, 21135)

# %%
noisy_speech = filtered_duration['filename'].to_list()
clean_speech = 'common_voice_zh-TW_' + filtered_duration['filename'].str[:8] + '_filtered.mp3'
clean_speech = clean_speech.to_list()

# %% [markdown]
# ### Train

# %%
path1 = '/content/drive/MyDrive/audio/noisy_train/'
path2 = '/content/drive/MyDrive/audio/clean_train/'
files1 = os.listdir(path1)
files2 = os.listdir(path2)

filtered_files1 = [f for f in files1 if f in noisy_speech]
filtered_files2 = [f for f in files2 if f in clean_speech]

print(len(files1), len(files2))
print(len(filtered_files1), len(filtered_files2))
# Out:
# 16876 16876
# 16876 16876

# %%
filtered_files1.sort()
filtered_files2.sort()
print(filtered_files1[:5])
print(filtered_files2[:5])

# %%
[f[:8] for f in filtered_files1] == [f.replace('common_voice_zh-TW_','').replace('_filtered.mp3','') for f in filtered_files2]

# %%
path_write = '/content/drive/MyDrive/Wave-U-Net/Datasets/MCV_ESC/trainset.txt'
with open(path_write, 'w+') as txt:
  for i in range(len(filtered_files1)):
    string = path1 + filtered_files1[i] + ' ' + path2 + filtered_files2[i]
    #print('string', string)
    txt.write(string + '\n')

# %% [markdown]
# ### Validation

# %%
path1 = '/content/drive/MyDrive/audio/noisy_valid/'
path2 = '/content/drive/MyDrive/audio/clean_valid/'
files1 = os.listdir(path1)
files2 = os.listdir(path2)

filtered_files1 = [f for f in files1 if f in noisy_speech]
filtered_files2 = [f for f in files2 if f in clean_speech]

print(len(files1), len(files2))
print(len(filtered_files1), len(filtered_files2))
# Out:
# 4021 4021
# 4021 4021

# %%
filtered_files1.sort()
filtered_files2.sort()
print(filtered_files1[:5])
print(filtered_files2[:5])

# %%
[f[:8] for f in filtered_files1] == [f.replace('common_voice_zh-TW_','').replace('_filtered.mp3','') for f in filtered_files2]

# %%
path_write = '/content/drive/MyDrive/Wave-U-Net/Datasets/MCV_ESC/validset.txt'
with open(path_write, 'w+') as txt:
  for i in range(len(filtered_files1)):
    string = path1 + filtered_files1[i] + ' ' + path2 + filtered_files2[i]
    #print('string', string)
    txt.write(string + '\n')

# %% [markdown]
# # Train Model

# %%
# !python train.py -C config/train/1129_train_01.json -R
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 40 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 2024-12-03 09:09:33.654492: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-03 09:09:33.671601: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-03 09:09:33.692583: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-03 09:09:33.699282: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-03 09:09:33.714826: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-03 09:09:34.903133: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /content/drive/MyDrive/Wave-U-Net/trainer/base_trainer.py:70: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(latest_model_path.as_posix(), map_location=self.device)
# Model checkpoint loaded. Training will begin in 601 epoch.
# Configurations are as follows:
# {
#   seed: 0,
#   description: "...des",
#   root_dir: "./Experiments/1129_train_01",
#   cudnn_deterministic: false,
#   trainer: {
#     module: "trainer.trainer",
#     main: "Trainer",
#     epochs: 750,
#     save_checkpoint_interval: 10,
#     validation: {
#       interval: 10,
#       find_max: true,
#       custom: {
#         visualize_audio_limit: 20,
#         visualize_waveform_limit: 20,
#         visualize_spectrogram_limit: 20,
#         sample_length: 16384,
#       },
#     },
#   },
#   model: {
#     module: "model.unet_basic",
#     main: "Model",
#     args: {},
#   },
#   loss_function: {
#     module: "model.loss",
#     main: "mse_loss",
#     args: {},
#   },
#   optimizer: {
#     lr: 0.001,
#     beta1: 0.9,
#     beta2: 0.999,
#   },
#   train_dataset: {
#     module: "dataset.waveform_dataset",
#     main: "Dataset",
#     args: {
#       dataset: "./Datasets/MCV_ESC/trainset.txt",
#       limit: null,
#       offset: 0,
#       sample_length: 16384,
#       mode: "train",
#     },
#   },
#   validation_dataset: {
#     module: "dataset.waveform_dataset",
#     main: "Dataset",
#     args: {
#       dataset: "./Datasets/MCV_ESC/validset.txt",
#       limit: 400,
#       offset: 0,
#       mode: "validation",
#     },
#   },
#   train_dataloader: {
#     batch_size: 32,
#     num_workers: 40,
#     shuffle: true,
#     pin_memory: true,
#   },
#   experiment_name: "1129_train_01",
#   config_path: "config/train/1129_train_01.json",
# }
# This project contains 1 networks, the number of the parameters:
# 	Network 1: 10.132802 million.
# The amount of parameters is 10.132802 million.
# ============== 601 epoch ==============
# [0 seconds] Begin training...
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 40 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# [755 seconds] End this epoch.
# ============== 602 epoch ==============
# [0 seconds] Begin training...
# [81 seconds] End this epoch.
# ============== 603 epoch ==============
# [0 seconds] Begin training...
# [82 seconds] End this epoch.
# ============== 604 epoch ==============
# [0 seconds] Begin training...
# [82 seconds] End this epoch.
# ============== 605 epoch ==============
# [0 seconds] Begin training...
# [82 seconds] End this epoch.
# ============== 606 epoch ==============
# [0 seconds] Begin training...
# [82 seconds] End this epoch.
# ============== 607 epoch ==============
# [0 seconds] Begin training...
# [82 seconds] End this epoch.
# ============== 608 epoch ==============
# [0 seconds] Begin training...
# [82 seconds] End this epoch.
# ============== 609 epoch ==============
# [0 seconds] Begin training...
# [83 seconds] End this epoch.
# ============== 610 epoch ==============
# [0 seconds] Begin training...
# 	 Saving 610 epoch model checkpoint...
# [84 seconds] Training is over. Validation is in progress...
# [660 seconds] End this epoch.
# ============== 611 epoch ==============
# [0 seconds] Begin training...
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 40 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# [74 seconds] End this epoch.
# ============== 612 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 613 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 614 epoch ==============
# [0 seconds] Begin training...
# [74 seconds] End this epoch.
# ============== 615 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 616 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 617 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 618 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 619 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 620 epoch ==============
# [0 seconds] Begin training...
# 	 Saving 620 epoch model checkpoint...
# [77 seconds] Training is over. Validation is in progress...
# [208 seconds] End this epoch.
# ============== 621 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 622 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 623 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 624 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 625 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 626 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 627 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 628 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 629 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 630 epoch ==============
# [0 seconds] Begin training...
# 	 Saving 630 epoch model checkpoint...
# [78 seconds] Training is over. Validation is in progress...
# [210 seconds] End this epoch.
# ============== 631 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 632 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 633 epoch ==============
# [0 seconds] Begin training...
# [77 seconds] End this epoch.
# ============== 634 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 635 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 636 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 637 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 638 epoch ==============
# [0 seconds] Begin training...
# [77 seconds] End this epoch.
# ============== 639 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 640 epoch ==============
# [0 seconds] Begin training...
# 	 Saving 640 epoch model checkpoint...
# [76 seconds] Training is over. Validation is in progress...
# [208 seconds] End this epoch.
# ============== 641 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 642 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 643 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 644 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 645 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 646 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 647 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 648 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 649 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 650 epoch ==============
# [0 seconds] Begin training...
# 	 Saving 650 epoch model checkpoint...
# [77 seconds] Training is over. Validation is in progress...
# [209 seconds] End this epoch.
# ============== 651 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 652 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 653 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 654 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 655 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 656 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 657 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 658 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 659 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 660 epoch ==============
# [0 seconds] Begin training...
# 	 Saving 660 epoch model checkpoint...
# [77 seconds] Training is over. Validation is in progress...
# [211 seconds] End this epoch.
# ============== 661 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 662 epoch ==============
# [0 seconds] Begin training...
# [77 seconds] End this epoch.
# ============== 663 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 664 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 665 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 666 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 667 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 668 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 669 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 670 epoch ==============
# [0 seconds] Begin training...
# 	 Saving 670 epoch model checkpoint...
# [77 seconds] Training is over. Validation is in progress...
# [209 seconds] End this epoch.
# ============== 671 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 672 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 673 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 674 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 675 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 676 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 677 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 678 epoch ==============
# [0 seconds] Begin training...
# [77 seconds] End this epoch.
# ============== 679 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 680 epoch ==============
# [0 seconds] Begin training...
# 	 Saving 680 epoch model checkpoint...
# [77 seconds] Training is over. Validation is in progress...
# [210 seconds] End this epoch.
# ============== 681 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 682 epoch ==============
# [0 seconds] Begin training...
# [74 seconds] End this epoch.
# ============== 683 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 684 epoch ==============
# [0 seconds] Begin training...
# [74 seconds] End this epoch.
# ============== 685 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 686 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 687 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 688 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 689 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 690 epoch ==============
# [0 seconds] Begin training...
# 	 Saving 690 epoch model checkpoint...
# [76 seconds] Training is over. Validation is in progress...
# [208 seconds] End this epoch.
# ============== 691 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 692 epoch ==============
# [0 seconds] Begin training...
# [74 seconds] End this epoch.
# ============== 693 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 694 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 695 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 696 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 697 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 698 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 699 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 700 epoch ==============
# [0 seconds] Begin training...
# 	 Saving 700 epoch model checkpoint...
# [77 seconds] Training is over. Validation is in progress...
# [209 seconds] End this epoch.
# ============== 701 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 702 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 703 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 704 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 705 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 706 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 707 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 708 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 709 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 710 epoch ==============
# [0 seconds] Begin training...
# 	 Saving 710 epoch model checkpoint...
# [76 seconds] Training is over. Validation is in progress...
# [208 seconds] End this epoch.
# ============== 711 epoch ==============
# [0 seconds] Begin training...
# [74 seconds] End this epoch.
# ============== 712 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 713 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 714 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 715 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 716 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 717 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 718 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 719 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 720 epoch ==============
# [0 seconds] Begin training...
# 	 Saving 720 epoch model checkpoint...
# [76 seconds] Training is over. Validation is in progress...
# [209 seconds] End this epoch.
# ============== 721 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 722 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 723 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 724 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 725 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 726 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 727 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 728 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 729 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 730 epoch ==============
# [0 seconds] Begin training...
# 	 Saving 730 epoch model checkpoint...
# [77 seconds] Training is over. Validation is in progress...
# [209 seconds] End this epoch.
# ============== 731 epoch ==============
# [0 seconds] Begin training...
# [77 seconds] End this epoch.
# ============== 732 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 733 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 734 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 735 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 736 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 737 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 738 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 739 epoch ==============
# [0 seconds] Begin training...
# [77 seconds] End this epoch.
# ============== 740 epoch ==============
# [0 seconds] Begin training...
# 	 Saving 740 epoch model checkpoint...
# [76 seconds] Training is over. Validation is in progress...
# [208 seconds] End this epoch.
# ============== 741 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 742 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 743 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 744 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 745 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 746 epoch ==============
# [0 seconds] Begin training...
# [76 seconds] End this epoch.
# ============== 747 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 748 epoch ==============
# [0 seconds] Begin training...
# [75 seconds] End this epoch.
# ============== 749 epoch ==============
# [0 seconds] Begin training...
# [77 seconds] End this epoch.
# ============== 750 epoch ==============
# [0 seconds] Begin training...
# 	 Saving 750 epoch model checkpoint...
# [78 seconds] Training is over. Validation is in progress...
# [211 seconds] End this epoch.
